# %% [markdown]
# **my first program**

# %%
print("hello my self vinay")
# Out:
# hello my self vinay

# %% [markdown]
# adiition

# %%
a=10
b=9
sum=a+b
print("addition is",sum)
# Out:
# addition is 19

# %% [markdown]
# multiplication of two or three numbers

# %%
a=2
b=2
mul=a*b
print("multiplication is ",mul)
# Out:
# multiplication is  4

# %% [markdown]
# division(finding the quotient and reminder of two numbers)

# %%
a=25
b=5
div=a/b
print(div)
# Out:
# 5.0

# %%
a=10
b=3
quoi=a/b
rem=a%b
print("quotient", quoi)
print("reminder",rem)
# Out:
# quotient 3.3333333333333335
# reminder 1

# %% [markdown]
# subtraction of two and three numbers

# %%
a=5
b=8
c=9
sub=a-b-c
print("subtration is",sub)
# Out:
# subtration is -12

# %% [markdown]
# square root of number

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# squaring of number

# %%
a=5
square=a**2
print(" square is", square)
# Out:
#  square is 25

# %% [markdown]
# cubeing

# %%
a=5
cube=a**3
print("cube is",cube)
# Out:
# cube is 125

# %% [markdown]
# DAY-02

# %% [markdown]
# tuples

# %%
tuple1=("hubballi","belagavi","haveri")
print(tuple1)
print(tuple1[1])
print(tuple1[2])
tuple3=tuple1+tuple1
tuple4=tuple1*2
print(tuple3)
print(tuple4)
# Out:
# ('hubballi', 'belagavi', 'haveri')
# belagavi
# haveri
# ('hubballi', 'belagavi', 'haveri', 'hubballi', 'belagavi', 'haveri')
# ('hubballi', 'belagavi', 'haveri', 'hubballi', 'belagavi', 'haveri')

# %% [markdown]
#  adding elents to tuple

# %%
x=("hubli","mysore","banglore","ballary")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
y[1]="bombay"
x=tuple(y)
print(x)
# Out:
# ('hubli', 'bombay', 'bombay', 'bombay')

# %% [markdown]
# sets
#
#
# 1. unordered
# 2.  Unchangeable
# 3. duplicates not allowed

# %%
set1={"Red","Black","Blue","Black"}
print(set1)
set1.add('purple')
print(set1)
set2={"ball","bat","wickets","net"}
set1.update(set2)
print(set1)
# Out:
# {'Blue', 'Black', 'Red'}
# {'purple', 'Blue', 'Black', 'Red'}
# {'purple', 'bat', 'ball', 'Red', 'Blue', 'wickets', 'Black', 'net'}

# %% [markdown]
# use of Dictionaries data type in python

# %%
Dict1= {"Name": "vinay",
       "Age": "21",
       "Address": "hubli","DOB": "21-03-2002"}
print(Dict1)
# Out:
# {'Name': 'vinay', 'Age': '21', 'Address': 'hubli', 'DOB': '21-03-2002'}

# %%
print(type(Dict1))
# Out:
# <class 'dict'>

# %%
dict2= dict(fruit="apple",Dessert="Ice")
print(dict2)
print(type(dict2))
# Out:
# {'fruit': 'apple', 'Dessert': 'Ice'}
# <class 'dict'>
